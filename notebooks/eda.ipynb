# %% [markdown]
# # EDA for Beam Prediction
# Exploring the processed dataset for RSRP and SINR correlations to the optimal beam indices.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
sys.path.append('..')

df = pd.read_csv('../data/processed/cleaned_dataset.csv')
df.head()

# %%
sns.pairplot(df[['RSRP', 'SINR', 'best_beam']].sample(1000), hue='best_beam')
plt.title('RSRP vs SINR by Beam')
plt.show()
